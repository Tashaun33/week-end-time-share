# %%
a=('Oh God my Occipital lobe is not or was Carbon monoxide.')
print(a)
input('Amen')


this was 1 notebook...


struggle is were id learn
down the rabbit hole, not to fail but prove the education.

plotting library like pandas

as we grow as data analysist , we will use AI, but with practice and work become less reliant on AI, as our knowledge grows

now is the worse, now we can only get better..... this after the project deadlines.

generative Ai most used for writing , large language model-.
to run 3 mile is not to drive  a car 3 miles, nothing learned

the processs of struggle, is human and can be personal, to see in the future where Generative AI is leading-.

no AI in school, or ten years ago.

probability-

now = graphic interface 'Dash Board'
I remember 10 x 10 x 10 in this room 2016 AD-
10 x 10 = 100
100 x 10 = 1000

teac her said STREAMLIT, not just using juypter note books

now is raw and crude way of producing data for comsumption,using dashboards is how to capture the customers and express the data , in high viz.

peace to Roman.
thanks teacher.
some kind words.
cheer boss....

this was 1 notebook


notes from class Monday 11th Aug 2025AD.
teacher Mr Vasi_ci

https://github.com/Code-Institute-Org/data-analytics-template
I can use this template for each and every project during and after code 16 week bootcamp.
data acquisition
extraction
feature engineering
one for loading

pip install -r requirements.txt
.venv\Scripts\activate
source. vene\scrpite\activate

this was 1 notebook


#hello, this is from class 15pm today. aug 8th 2025 AD.
import pandas as pd
pd.dataset()

this was i notebook

#hello, this is from class 15pm today. aug 8th 2025 AD.
import pandas as pd
pd.dataset()


this was 1 notebook 


a=('class at 15pm')
print(a)
input('please press enter')

b=('visualation assessment for next week.')
print(b)
input('press enter')

c=('not working in the LMS.')
print(c)
input('press enter')

 
d=('local work in GITHUB.')
print(d)
input('press enter')

e=('a template in GitHub is used to create a REPO..--')
print(e)
input('press enter')

f=('open GitHub repository for any project.')
print(f)
input('press enter')

g=('A template is different from a standard REPO.')
print(g)
input('press enter')

h=('green button. create a template- use this template.')
print(h)
input('press emter')

i=('create this in your own space-')
print(i)
input('press enter')


J=('forking a project- some elses work, you offer changes tobe accepted or rejected.')
print(j)
input('press enter')

k=('fork not collaborate- as a junior developer')
print(k)
input('press enter')

l=('as an individual I could be better off forking-')
print(l)
input('press enter')

m=('hackaphon in groups of 3,4,5. future projects.')
print(m)
input('press enter')


n=('git ignore is where to to put works that wont push up to GitHub nd public space')
print(n)
input('press enter')


o=('the PROJECT next week will need a READ.Me document telling an assessor how to use the project.')
print(o)
input('press enter')

p=('title, descriptions, ethics, legal statements, some ideas on the design of the projects.')
print(p)
input('press enter')


q=('#it doesnt make a huge difference to the final project....')
print(q)
input('press enter')

r=('custom project vs template data set, only have 2 days.')
print(r)
input('press enter')


s=('others may have 1 year and then create there own custom projects.')
print(s)
input('press enter')

t=('tell VS Code just to open files in personal computer directory.')
print(t)
input('press enter') 

u=('THE PROJECT,')
print(u)
input('press enter') 

v=('2days- extraction,.....cleaning data,.....-feature engineering........document what I have done......a markdown comment,')
print(v)
input('press enter')

w=('taking on multiple roles.......cleaning......extractions ---as Data analysist.....charts....identify which chart')
print(w)
input('press enter')

x=('stick to 2day shedule--- as project manager.....')
print(x)
input('press enter')

y=('all done on LMS bring the skills and practice into play...you there get off the subs bench.... hahahah')
print(y)
input('press enter')

z=('all im submitting is a juypter notebook and a read.me.')
print(z)
input('press enter')


aa=('class done well to perceive the challenge of the up and coming project today, Good luck everybody for next week.')
print(aa)
input('press enter')

bb=('can make a start before Tuesday.....****Teacher Mr Niel said so-......push project into GitHub.')
print(bb)
input('press enter')

cc=('---This is My Project-- as a title in the Repo....set up items on can dan board????')
print(cc)
input('press enter')

dd=('by the end of first day patterns setup visualations prepared to sort.....put candam link into the read me file')
print(dd)
input('press enter')

ee=('need to use at least 2 librarys...need to make it interactive which is only available on Plotly., but can use')
print(ee)
input('press enter')

ff=('matplotlib and seaborn.')
print(ff)
input('press enter')


gg=('explain the rationale...prove or disprove the hypothesis equally valid-')
print(gg)
input('press input')

hh=('second  day is for more advanced visualations.....problem solving--')
print(hh)
input('press enter')


ii=('deal well with distractions- focus on the project..we can use Co-Pilot to help.')
print(ii)
input('press enter')

jj=('project management against splitting up the tasks...can view the document and mark sheet in the LMS.')
print(jj)
input('press enter')

kk=('have to present project to VASI..16 week bootcamp 9am to 5pm, we are supposed to come up with it.')
print(kk)
input('press enter')

ll=('step by step in the LMS.......Teacher Niel said can refer to the LMS...leftjoin, -rightjoin, near-nonconvention')
print(ll)
input('press enter')

mm=('keep  cheat sheet handy,.link the lms type stuff to Vs code via txt.- command..acknowledge link to Kaggle on GitHub,')
print(mm)
input('press enter')

nn=('maybe in the readme...suggested data sources on LMS. Raw Data sets- on Kaggle..go to the dataset not the project of someone else.')
print(nn)
input('press enter')

oo=('predictions.....description......diagnostic.......prescriptive')
print(oo)
input('press enter')


pp=('Teacher Niel advice .structure- do a commit on a piece of working code-')
print(pp)
input('press enter')

qq=('did you do things in a logical style:...bit,....by bit, .....by bit..assessor wants to to know how you progressed.')
print(qq)
input('press enter')

rr=('not just one massive commit 2 minutes before deadline time...any problems with json,:right click download - zip file...csv.')
print(rr)
input('press enter')


ss=('git hub is not a live editor...its just a repository......in the past code didnt run on GitHub')
print(ss)
input('press enter')

tt=('recreate juypter notebook learned from the LMS as the project.')
print(tt)
input('press enter')

uu=('im the only one running the project on vs code on my machine...…meet all criteria for assessment.')
print(uu)
input('press enter')

vv=('give it an attribution. I got this code from somewhere....screen shots in Read.me, easyway to build up.')
print(vv)
input('press enter')

ww=('END OF REVISION NOTE FROM CLASS AS STUDEN FROM TEACHER.')
print(ww)
input('end of revision note press enter')

# %% [markdown]
# this is the way to do, as it bunches the notes together quite well, i might not have gathered them this way but here it shows at least 1 collection of that way.

# %%
a=('**class today lead by Teacher  Mr Niel.')
print(a)
input('please press enter')

b=('11am sharpe.')
print(b)
input('press enter')

c=('Aug 8th 2025 AD.')
print(c)
input('press enter')


d=('***we as Data analysists are looking, working towards the discovery of:')
print(d)
input('press enter')

e=('trends , patterns, and relationships, correlation,')
print(e)
input('print enter')

f=('certain events and trend-')
print(f)
input('print enter')

g=('30 year matplotlib has been around.')
print(g)
input('press enter')

h=('trends over time.')
print(h)
input('press enter')


i=('traditionaly: time lines x = axes left to right.')
print(i)
input('press enter')

j=('this Forum')
print(j)
input('press enter')

k=('statistics')
print(k)
input('press enter')

l=('FACTS are my FRIENDS')
print(l)
input('press enter')

m=('getting more information using applied data analyistics')
print(m)
input('press enter')

n=('-something out of the ordinary- for instance. HIP-HOP')
print(n)
input('press enter')

o=('***histograms use of bins, bin sizes')
print(o)
input('press enter')

p=('charts are good for this.')
print(p)
input('press enter')


q=('-comparative analysis- search inn each chart forr insight.quit')
print(q)
input('press enter')

r=('timeline reads from left to right even back in ancient Greece.')
print(r)
input('press enter')

s=('if things were in Japan we would be looking at a complete6y different style.')
print(s)
input('press enter')

t=('interpretation')
print(t)
input('press input')

u=('ultimately trying to show someone a chart or graph, best not fail in that quest for lack of display technique for the given data.')
print(u)
input('press enter')

v=('in the up and coming project choose one of he existing project before time is wasted')
print(v)
input('press enter')

w=('choose one of the Five 5. Teacher Niel said I could.')
print(w)
input('press enter')


x=('Therefore I predict-..... based on the statistics and the graph as a tool.')
print(x)
input('press enter')

y=('put a markdown on the LMS as I work down through it.')
print(y)
input('press enter')

z=('#as sort of an explanation-underneath')
print(z)
input('press enter')


aa=(' Question,\\- can categories be used into numbers.?????')
print(aa)
input('press enter')

bb=('#dont choose random synthectic dat set, no information')
print(bb)
input('press enter')

cc=('#make dull charts')
print(cc)
input('press enter')

dd=('#choose real data set go to Kaggle for the best information thats why its there.')
print(dd)
input('press enter')


ee=('Kaggle has best data set chosen for statictics data analysis.')
print(ee)
input('press enter')

ff=('explain up-line or down-line!! , for if its flat-line theres nothing to explain. on a bar chart for example.')
print(ff)
input('press enter')

gg=('whats the correlation.??? find the missing unexplained correlation/s.!')
print(gg)
input('press enter')

hh=('--  quantity should be a interger')
print(hh)
input('press enter')

ii=('££ is more like a value that a quantity')
print(ii)
input('press enter')

jj=('this is the LANGUAGE of DATA ANALYTICS.')
print(jj)
input('press enter')

kk=('cleaning might be spaces or grammer-unique instances.')
print(kk)
input('press enter')

ll=('#NAN = Not A Number')
print(ll)
input('press enter')

mm=('look for data cleaning in Pandas.')
print(mm)
input('press enter')

NN='(HERE IS THE END OF NOTES TAKEN FROM CLASS AS STUDENT FROM A TEACHER...')
print(nn)
input(' use this as a revision suppliment, please press enter')


this was 1 notebook.


a=('Oh God my Occipital lobe is not or was Carbon monoxide.')
print(a)
input('Amen please press enter to continue')

this was 1 notebook.


#living in the spirit-.
input('please do, press enter')
#PII-

#pii is things like address and bank details
#you're identity,
#data that can be used directly to identify you'
#and or combination of data can be used against you.
#handle it carefully.
#laws in uk and Europe,
input('please press enter')

#GDPR-

#ethics and morals-???????

#different policies for collecting and processing data


#laws protect the data from mis-use.
#need consent for data to be collected.
#data has tobe necessary to collect via the Authorities.
#need a reason, prove you're not Bias for collecting data
#GDPR applies to all living in EU and UK
#e.g this GDPR doesn't apply to that USA.
input('please press enter')

#DATA Augumentation-

#cleaning the data????????

#it is increasing the diversity of the data set, 
#rather than going away collecting new data, take youre existing data and work on them e.g images rotate them, clip them, enlarge them.
#allows you to work in all conditions not just perfect conditions.


input('please press enter') 
#Quote of teacher Niel.
#A good programmer is also A lazy programmer-
#feature engine sits on top of pandas, save repetition of easy tasks.
#use of feature engine as a tool,

#computers like to work in/with numbers

#logorythmic 0-1 normalise.
#Data Augumentations is a good practice where cost is an issue. 
#x-ray images good to Augumen
#cctv  images cheaper than Augumen
# python better than excel to protect data being altered automatically.
#python strings-interger-floats
#excel changing numbers into dates

#might not be right to normalise a data set.

input('please press enter')
#data the new OIL

#moving onto VS code
#moving away from embedded LMS from next week to work more locally.

#use the stuff niel gave us  not just how but why we make charts.
#the Lms is importing seaborn even though not doing any seaborn.

this was 1 notebook

# %% [markdown]
# this is futher progress into note collaboration-

# %%
*class today lead by Teacher  Mr Niel.
11am sharpe.
Aug 8th 2025 AD.

***we as Data analysists are looking, working towards the discovery of:

trends , patterns, and relationships, correlation,
certain events and trend-

30 year matplotlib has been around.

trends over time.

traditionaly: time lines x = axes left to right.

this Forum

statistics
FACTS are my FRIENDS

'getting more information using applied data analyistics'

-something out of the ordinary- for instance. HIP-HOP

***histograms use of bins, bin sizes 
charts are good for this.

****-comparative analysis- search in each chart for insight.
timeline reads from left to right even back in ancient Greece.

if things were in Japan we would be looking at a completey different style.

interpretation

ultimately trying to show someone a chart or graph, best not fail in that quest for lack of display technique for the given data.

***in the up and coming project choose one of he existing project before time is wasted
choose one of the Five 5. Teacher Niel said I could.

***'Therefore I predict-.....' based on the statistics and the graph as a tool.
put a markdown on the LMS as I work down through it.
as sort of an explanation-underneath


*** Question,\\- can categories be used into numbers.?????
don't choose random synthectic dat set, no information 
make dull charts
choose real data set go to Kaggle for the best information that's why its there.

Kaggle has best data set chosen for statictics data analysis.
explain up-line or down-line!! , for if its flat-line theres nothing to explain. on a bar chart for example.
whats the correlation.??? find the missing unexplained correlation/s.!

****))--  quantity should be a interger
££ is more like a value that a quantity
this is the LANGUAGE of DATA ANALYTICS.

cleaning might be spaces or grammer-unique instances.
NAN= Not A Number

look for data cleaning in Pandas.
    


this was 1 notebook

# %% [markdown]
# this is cool for now...

# %%
from datetime import datetime

x = datetime.now()
print(x)
print(x.year)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# 2025-08-30 15:24:17.249120
# 2025

# %% [markdown]
# welcome to my outputs- produce of my efforts-

# %%
df = pd.DataFrame(data={'Col1':np.random.randint(low=0,high=50,size=10),
                        'Col2':np.random.randn(10),
                        'Col3':['A','B','C','A','A','C','D','B','A','A'],
                        'Col4':np.random.choice([True, False],size=10),
                        'Col5':np.random.randint(low=1,high=4,size=10)},
                  index=pd.date_range(start='01/01/2021', periods=10, freq='M'))
df
# Out:
#             Col1      Col2 Col3   Col4  Col5
# 2021-01-31     6  0.312222    A  False     3
# 2021-02-28    21 -1.374688    B   True     1
# 2021-03-31    28  0.752222    C   True     2
# 2021-04-30    49  1.383496    A   True     2
# 2021-05-31    15 -0.065787    A  False     3
# 2021-06-30    28  0.568229    C   True     1
# 2021-07-31     9 -0.693455    D  False     1
# 2021-08-31    26 -0.431765    B   True     1
# 2021-09-30    49  0.601709    A   True     2
# 2021-10-31    37  0.967954    A   True     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2021-01-31 to 2021-10-31
# Freq: M
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    10 non-null     int32
#  1   Col2    10 non-null     float64
#  2   Col3    10 non-null     object
#  3   Col4    10 non-null     bool
#  4   Col5    10 non-null     int32
# dtypes: bool(1), float64(1), int32(2), object(1)
# memory usage: 330.0+ bytes

# %%
np.random.seed(seed=5)
x = np.random.randn(24)

plt.plot(x) 
plt.xlabel('time')
plt.ylabel('effort')
plt.title('Mister B')
plt.show()

# %%
x = np.linspace(0, 10, 500)
fig, axes = plt.subplots(figsize=(8,4))
axes.plot(x, np.sin(x), color='m', linewidth=4 , linestyle=':', label='sin(x)')
axes.plot(x, x * np.sin(x),color='#B35946', linestyle='-.', label='x * sin(x)')
axes.legend()
plt.show()

# %%
x = np.linspace(0, 10, 300)
fig, axes = plt.subplots(figsize=(10,6))
axes.scatter(x=x,y= np.random.randn(300),marker='2')
plt.show()

# %%
x = np.linspace(0, 10, 500)
plt.plot(x, np.sin(x))
plt.axhline(y=0.5, color='r', linestyle='dashed',linewidth=2)
plt.axvline(x=8, color='g', linestyle=':')

plt.show()

# %%
x = np.linspace(0, 10, 275)
y = np.random.randn(275)

fig, axes = plt.subplots()
axes.scatter(x=x,y=y)
axes.grid(True, linestyle='-.', axis='y')
plt.show()

# %%
x = np.linspace(0, 10, 500)
plt.plot(x, np.sin(x))

plt.text(x=2, y=0, s='mister B corporation', fontsize=12, c='r')
plt.show()

# %%
x = np.linspace(0, 10,500)
plt.plot(x, np.sin(3*x) * x)
plt.title("Nice title!")
plt.tight_layout()
plt.savefig('created_image.png', bbox_inches='tight', dpi=150)

# %%
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('brain_networks')
df =df.head(10)
df.tail(5)
# Out:
#   network                    1                 1.1                    2  \
# 5       2    60.99776840209961   63.43879318237305   -51.10858154296875
# 6       3   18.514867782592773   12.65715789794922  -34.576602935791016
# 7       4  -2.5273923873901367  -63.10466766357422    -13.8141508102417
# 8       5   -24.90679168701172     -51.19189453125   -29.86799430847168
# 9       6   17.273710250854492  0.5400829315185547   18.649370193481445
#
#                    2.1                    3                  3.1  \
# 5  -13.561346054077148  -18.842947006225586  -1.2146592140197754
# 6  -32.665958404541016   -7.420454025268555   17.119447708129886
# 7   -15.83798885345459   -45.21692657470703   3.4835495948791504
# 8  -27.840293884277344   -24.45510673522949   47.115760803222656
# 9   -9.105488777160645  -2.1172263622283936    87.95771026611328
#
#                     4                 4.1                   5  ...  \
# 5   -65.5758056640625  -85.77742767333984  19.247453689575195  ...
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def sinplot(n=10, flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, n + 1):
        plt.plot(x, np.sin(x + i * .5) * (n + 2 - i) * flip)

sinplot()

# %%
sns.set_theme()
sinplot()

# %% [markdown]
# yes that better, looking and feeling like, a fluid movement through the motions.  growth mindset
